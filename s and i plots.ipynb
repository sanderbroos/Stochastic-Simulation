243929639, 0.03105017930751393, 0.04039600950258616, 0.028591594567177418, 0.03302589660182172, 0.03968519987463575, 0.030356590977404653, 0.02997886849946353, 0.033139241486409315, 0.03085830000401784, 0.032221074, 0.03743140262742882, 0.03424426214794645, 0.027318061887321745, 0.03358269915824254, 0.024431635550342994, 0.031544735451506954, 0.030090634490943947, 0.03628010101044367, 0.03710493067598496, 0.02908536591508335, 0.03850151191170242, 0.034933636930589755, 0.03514100718405222, 0.03612294820207446]]

plt.figure(figsize = (15,9))

CI_95 = list(map(lambda x:(1.96*x)/np.sqrt(50), result2[2]))
plt.errorbar(result2[0][5:], result2[1][5:], yerr = CI_95[5:], fmt = '.')

plt.title('$A_{i,s} - A_{j,s} \pm$ 95% CI \n $i = 100$ , $ j = 7, 8,...,i-1$, $n = 50$', fontsize = 20 )
plt.ylabel('$A_{i,s} - A_{j,s}$', fontsize = 20)
plt.xlabel(r'$j$', fontsize = 20)
plt.hlines(0.1, xmin = 0, xmax = 100, ls = 'dotted', color = 'gray', label = '$i = 0.1$')

plt.legend(fontsize = 20)
plt.show()

# %%
def pre_select(mandelbrot_results, s, i, buffer=1):
    values, coordinates = mandelbrot_results
    search_blocks = []
    x_block = (coordinates[0][1][0]-coordinates[0][0][0])
    y_block = (coordinates[0][0][1]-coordinates[1][0][1])

    for column in range(len(values)):
        for row in range(len(values[column])):
            if values[column][row] >= n_iterations - 2:
                x_coor, y_coor = coordinates[column][row]

                for buffer_x in range(-buffer,buffer+1):
                    for buffer_y in range(-buffer,buffer+1):
                        new_block_x = x_coor + buffer_x*x_block
                        new_block_y = y_coor + buffer_y*y_block

                        already_in_list = False
                        for elem in search_blocks:
                            if abs(new_block_x-elem[0]) < x_block/10 and abs(new_block_y-elem[1]) < y_block/10:
                                already_in_list = True
                        
                        if not already_in_list:
                            search_blocks.append((new_block_x, new_block_y))
                
    return search_blocks
    
    x_values = []
    y_values = []

    for _ in range(s):
        block_coordinates = search_blocks[random.randint(0, len(search_blocks))]
        x_coor = block_coordinates[0]
        y_coor = block_coordinates[1]

        x_values.append(random.uniform(block_coordinates[0]-x_block/2, block_coordinates[0]+x_block/2))
        y_values.append(random.uniform(block_coordinates[1]-y_block/2, block_coordinates[1]+y_block/2))

    in_area, x_in_area, y_in_area = monte_carlo_mandelbrot(x_values, y_values, i)    
    area = x_block*y_block*len(search_blocks)*in_area/float(s)

    print(f"Area = {area}")
    plt.scatter(x_values, y_values, color='lightgrey', label='Search Area')
    plt.scatter(x_in_area, y_in_area, label='Mandelbrot Area')
    plt.legend()
    plt.show()

x_resolution = 50
n_iterations = 10

mandelbrot_results = mandelbrot(x_start = -2, 
                                x_end = 1, 
                                y_start = -1.5, 
                                y_end = 1.5, 
                                x_resolution = x_resolution, 
                                n_iterations = n_iterations,
                                threshold = 2)

pre_select(mandelbrot_results, 50000, 1000, 1)

# %%
df_random = pd.read_csv('results/randomsampling_n100_i50.csv')
df_latin = pd.read_csv('results/latinhypercubesampling_n100_i50_2.csv')
df_ortho2 = pd.read_csv('results/orthogonalsampling_n100_i50_div2.csv')
df_ortho5 = pd.read_csv('results/orthogonalsampling_n100_i50_div5.csv')
df_preset = pd.read_csv('results/preset_n100_i50.csv')

df_random['Mean'] = df_random.iloc[:,1:-1].mean(axis = 1)
df_random['Sample std'] = df_random.iloc[:,1:-1].std(axis = 1 )
df_random['95% CI'] = (1.96 * df_random['Sample std']) / np.sqrt(100)


df_latin['Mean'] = df_latin.iloc[:,1:-1].mean(axis = 1)
df_latin['Sample std'] = df_latin.iloc[:,1:-1].std(axis = 1 )
df_latin['95% CI'] = (1.96 * df_latin['Sample std']) / np.sqrt(100)

df_ortho2['Mean'] = df_ortho2.iloc[:,1:-1].mean(axis = 1)
df_ortho2['Sample std'] = df_ortho2.iloc[:,1:-1].std(axis = 1 )
df_ortho2['95% CI'] = (1.96 * df_ortho2['Sample std']) / np.sqrt(100)

df_ortho5['Mean'] = df_ortho5.iloc[:,1:-1].mean(axis = 1)
df_ortho5['Sample std'] = df_ortho5.iloc[:,1:-1].std(axis = 1 )
df_ortho5['95% CI'] = (1.96 * df_ortho5['Sample std']) / np.sqrt(100)

df_preset['Mean'] = df_preset.iloc[:,1:-1].mean(axis = 1)
df_preset['Sample std'] = df_preset.iloc[:,1:-1].std(axis = 1 )
df_preset['95% CI'] = (1.96 * df_preset['Sample std']) / np.sqrt(100)

# %%
figs, axs = plt.subplots(5,1, sharex = True, sharey = True, figsize = (15,20))
plt.suptitle('$A_{i,s} \pm$ 95% CI, n = 100, i = 50', fontsize = 20)

axs[0].plot(df_random['s'], df_random['Mean'], label = 'Random sampling')
axs[0].fill_between(df_random['s'], df_random['Mean'] - df_random['95% CI'], df_random['Mean'] + df_random['95% CI'], alpha = 0.2)
axs[0].set_ylabel('$A_{i,s}$', fontsize = 10)
axs[0].set_title('Pure random sampling')


axs[1].plot(df_latin['s'], df_latin['Mean'], label = 'Latin hypercube sampling', color = 'red')
axs[1].fill_between(df_latin['s'], df_latin['Mean'] - df_latin['95% CI'], df_latin['Mean'] + df_latin['95% CI'], color = 'red', alpha = 0.2)
# axs[1].set_yticks(np.linspace(1.54, 1.62, 5))
axs[1].set_ylabel('$A_{i,s}$', fontsize = 10)
axs[1].set_title('Latin hypercube sampling')

axs[2].plot(df_ortho2['s'], df_ortho2['Mean'], label = 'Orthogonal sampling, division = 2', color = 'green')
axs[2].fill_between(df_ortho2['s'], df_ortho2['Mean'] - df_ortho2['95% CI'], df_ortho2['Mean'] + df_ortho2['95% CI'], color = 'green', alpha = 0.2)
# axs[2].set_yticks(np.linspace(1.54, 1.62, 5))
axs[2].set_ylabel('$A_{i,s}$', fontsize = 10)
axs[2].set_title('Orthogonal sampling, 2 divisions')

axs[3].plot(df_ortho5['s'], df_ortho5['Mean'], label = 'Orthogonal sampling, division = 5', color = 'c')
axs[3].fill_between(df_ortho5['s'], df_ortho5['Mean'] - df_ortho5['95% CI'], df_ortho5['Mean'] + df_ortho5['95% CI'], color = 'cyan',alpha = 0.2)
# axs[3].set_yticks(np.linspace(1.54, 1.62, 5))
axs[3].set_ylabel('$A_{i,s}$', fontsize = 10)
axs[3].set_title('Orthogonal sampling, 5 divisions')
axs[3].set_xlabel('$s$')

axs[4].plot(df_preset['s'], df_preset['Mean'], label = 'Orthogonal sampling, division = 5', color = 'm')
axs[4].fill_between(df_preset['s'], df_preset['Mean'] - df_preset['95% CI'], df_preset['Mean'] + df_preset['95% CI'], color = 'm',alpha = 0.2)
axs[4].set_ylabel('$A_{i,s}$', fontsize = 10)
axs[4].set_title('Selective search area')
axs[4].set_xlabel('$s$')
plt.show()

# %%
plt.figure(figsize = (15,10))


plt.plot(df_random['s'], 2 * df_random['95% CI'], 'b.', label = 'Random sampling')
plt.plot(df_latin['s'], 2 * df_latin['95% CI'], 'r.', label = 'Latin hypercube sampling')
plt.plot(df_ortho2['s'], 2 * df_ortho2['95% CI'], 'g.', label = 'Orthogonal sampling, division = 2')
plt.plot(df_ortho5['s'], 2 * df_ortho5['95% CI'], 'c.', label = 'Orthogonal sampling, division = 5')
plt.plot(df_preset['s'], 2 * df_preset['95% CI'], 'm.', label = 'Preset')

plt.xscale('log')
plt.yscale('log')
plt.legend(fontsize = 15)
plt.title('Radius $a$ of 95% Confidence interval for $A_{i,s}$ \n $i = 50, n = 100$', fontsize = 20)
plt.ylabel('a', fontsize = 15, rotation = 0)
plt.xlabel('s', fontsize = 15)
plt.show()


plt.figure(figsize = (15,10))

plt.plot(df_random['s'], 2 * df_random['95% CI'], 'b-', label = 'Random sampling')
plt.plot(df_latin['s'], 2 * df_latin['95% CI'], 'r-', label = 'Latin hypercube sampling')
plt.plot(df_ortho2['s'], 2 * df_ortho2['95% CI'], 'g-', label = 'Orthogonal sampling, division = 2')
plt.plot(df_ortho5['s'], 2 * df_ortho5['95% CI'], 'orange-', label = 'Orthogonal sampling, division = 5')

# plt.xscale('log')
# plt.yscale('log')
plt.legend()
plt.title('Width of 95% confidence interval for area of the Mandelbrot set')
plt.ylabel('Width of CI')
plt.xlabel('s')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_340/290951395.py in <module>
#      22 plt.plot(df_latin['s'], 2 * df_latin['95% CI'], 'r-', label = 'Latin hypercube sampling')
#      23 plt.plot(df_ortho2['s'], 2 * df_ortho2['95% CI'], 'g-', label = 'Orthogonal sampling, division = 2')
# ---> 24 plt.plot(df_ortho5['s'], 2 * df_ortho5['95% CI'], 'orange-', label = 'Orthogonal sampling, division = 5')
#      25
#      26 # plt.xscale('log')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
